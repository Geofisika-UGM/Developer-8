# %% [markdown]
# ## <center>KEMENTRIAN PENDIDIKAN DAN KEBUDAYAAN
# ## <center>PROGRAM STUDI GEOFISIKA JURUSAN FISIKA
# ## <center>FAKULTAS MATEMATIKA DAN ILMU PENGETAHUAN ALAM
# # <center>UNIVERSITAS GADJAH MADA
# ***
# ## <center>PRAKTIKUM METODE KOMPUTASI
# ## <center>LAPORAN FINAL PROJECT
# ## <center>'CONVOLUTION'
# # <p>
#
# <img src="http://www.luk.staff.ugm.ac.id/logo/UGM/Resmi/Hitam-putih.gif" width="300" height="300" />
#
# # <p>
# # <p>
# ### <center>DISUSUN OLEH :
# #### <center>KELOMPOK 8
# #### <center>1. HARDHYA FALAH PRIANGGA         (21/478246/PA/20737)
# #### <center>2. MOKHAMMAD WAHYU PAMUNGKAS      (21/475440/PA/20578)
# #### <center>3. MUSYAFFA RAKHA DZAKIYUWANA     (21/481301/PA/20954)
# #### <center>4. TAKWA OKEDA PALIT              (21/477089/PA/20628)
# #### <center>5. TSABITA SALSABILAH ALIYAS BETA (21/480731/PA/20898)
# #### <center>6. VINSA NUR AZHARIA PUTRI        (21/482479/PA/21038)
# ***
# ## <center>YOGYAKARTA
# ## <center>NOVEMBER
# ## <center>2022

# %% [markdown]
# #### MINGGU KE-1
#
# pada minggu pertama ini, dilakukan pembagian kelompok oleh para asisten. setelah dilakukan pembagian kelompok,
# dilakukan pembagian judul project. selain pembagian kelompok dan judul, dilakukan pula pembagian asisten yang
# mendampingi setiap kelompoknya. pada kelompok 8 ini, kami mendapatkan judul 'Convolution' pada final project
# kali ini. di Convolution ini, input yang diperlukan agar menghasilkan seismometer synthetic adalah ricker wavelet
# dan coefficient reflectivity. kemudian dari kedua input tersebut, dilakukan konvolusi dan menghasilkan output
# sesuai yang diperintahkan.
#
# progress :
# 1. bertanya-tanya kepada asisten yang mendampingi kelompok kami terkait garis besar dari code yang akan dibuat
# 2. melakukan pencarian dari berbagai sumber terkait konvolusi
#
# kendala :
# 1. belum menemukan kendala
#
#
#
#
# #### MINGGU KE-2
#
# pada minggu ini, setiap kelompok ditargetkan dapat menyelesaikan core program dari masing-masing
# project.
#
# progress :
# 1. kami melakukan beberapa pencarian dari berbagai sumber terkait konvolusi
# 2. bertanya-tanya kepada asisten yang mendampingi kelompok kami terkait core program yang telah kami buat
# 3. telah dapat menyelesaikan core program, tetapi belum maksimal
#
# kendala :
# 1. masih menggunakan numpy untuk menjalankan fungsi konvolusi
#
#
#
#
# #### MINGGU KE-3
#
# pada minggu ini, setelah didapatkan core program masing-masing kelompok diharapkan mampu melakukan optimasi
# pada masing-masing program yang telah dibuat sebelumnya.
#
# progress :
# 1. melakukan penyempurnaan pada core program
# 2. telah dapat melakukan plotting grafik wavelet, koefisien refleksi, dan konvolusi
# 3. melakukan pencarian modul pengganti numpy untuk menjalankan fungsi konvolusi
#
# kendala :
# 1. masih belum menemukan code yang dapat menggantikan modul numpy untuk menjalankan fungsi konvolusi
# 2. masih belum melakukan optimasi program karena masih berusaha menyempurnakan core program yang sebelumnya
# 3. telah dapat melakukan plot grafik koefisien reflectivity, tetapi masih belum dapat keluar outputnya
# 4. kesulitan dalam mencari modul pengganti numpy untuk menjalankan fungsi konvolusi
#
#
#
#
# #### MINGGU KE-4
#
# pada minggu ini, setelah dilakukan optimasi program, tiap-tiap kelompok diharapkan dapat membuat CLI dan GUI
# dari program yang sebelumnya telah disusun.
#
# progress :
# 1. telah melakukan perbaikan pada program yang telah dibuat sebelumnya
# 2. sedang berusaha menyelesaikan CLI dan GUI
# 3. masih melakukan pencarian modul pengganti numpy untuk menjalankan fungsi konvolusi
#
# kendala :
# 1. belum melakukan optimasi pada program yang dibuat
# 2. kesulitan dalam mencari modul pengganti numpy untuk menjalankan fungsi konvolusi,
